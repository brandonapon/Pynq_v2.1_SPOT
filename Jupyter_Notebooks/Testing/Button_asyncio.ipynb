# %%
from pynq import PL
from pynq.overlays.base import BaseOverlay

base = BaseOverlay("base.bit")

# %%
for values in base.ip_dict:
    print(values)
    for thing in base.ip_dict[values]:
        print(values, ':', base.ip_dict[values][thing])
# Out:
# audio_direct_0
# audio_direct_0 : 1136656384
# audio_direct_0 : 65536
# audio_direct_0 : xilinx.com:user:audio_direct:1.1
# audio_direct_0 : None
# audio_direct_0 : {}
# audio_direct_0 : {'sel_direct': {'index': 3, 'state': None, 'pins': {'audio_path_sel/Dout', 'audio_direct_0/sel_direct'}}}
# audio_direct_0 : audio_direct_0
# audio_direct_0 : <class 'pynq.lib.audio.AudioDirect'>
# trace_analyzer_pmoda/axi_dma_0
# trace_analyzer_pmoda/axi_dma_0 : 2151677952
# trace_analyzer_pmoda/axi_dma_0 : 65536
# trace_analyzer_pmoda/axi_dma_0 : xilinx.com:ip:axi_dma:7.1
# trace_analyzer_pmoda/axi_dma_0 : None
# trace_analyzer_pmoda/axi_dma_0 : {'s2mm_introut': {'controller': 'system_interrupts', 'index': 6, 'fullpath': 'trace_analyzer_pmoda/axi_dma_0/s2mm_introut'}}
# trace_analyzer_pmoda/axi_dma_0 : {}
# trace_analyzer_pmoda/axi_dma_0 : trace_analyzer_pmoda/axi_dma_0
# trace_analyzer_pmoda/axi_dma_0 : <class 'pynq.lib.dma.DMA'>
# trace_analyzer_arduino/axi_dma_0
# trace_analyzer_arduino/axi_dma_0 : 2151743488
# trace_analyzer_arduino/axi_dma_0 : 65536
# trace_analyzer_arduino/axi_dma_0 : xilinx.com:ip:axi_dma:7.1
# trace_analyzer_arduino/axi_dma_0 : None
# trace_analyzer_arduino/axi_dma_0 : {'s2mm_introut': {'controller': 'system_interrupts', 'index': 7, 'fullpath': 'trace_analyzer_arduino/axi_dma_0/s2mm_introut'}}
# trace_analyzer_arduino/axi_dma_0 : {}
# trace_analyzer_arduino/axi_dma_0 : trace_analyzer_arduino/axi_dma_0
# trace_analyzer_arduino/axi_dma_0 : <class 'pynq.lib.dma.DMA'>
# video/hdmi_out/frontend/axi_dynclk
# video/hdmi_out/frontend/axi_dynclk : 1136721920
# video/hdmi_out/frontend/axi_dynclk : 65536
# video/hdmi_out/frontend/axi_dynclk : digilentinc.com:ip:axi_dynclk:1.0
# video/hdmi_out/frontend/axi_dynclk : None
# video/hdmi_out/frontend/axi_dynclk : {}
# video/hdmi_out/frontend/axi_dynclk : {}
# video/hdmi_out/frontend/axi_dynclk : video/hdmi_out/frontend/axi_dynclk
# video/hdmi_out/frontend/axi_dynclk : <class 'pynq.overlay.DefaultIP'>
# video/hdmi_in/frontend/axi_gpio_hdmiin
# video/hdmi_in/frontend/axi_gpio_hdmiin : 1092747264
# video/hdmi_in/frontend/axi_gpio_hdmiin : 65536
# video/hdmi_in/frontend/axi_gpio_hdmiin : xilinx.com:ip:axi_gpio:2.0
# video/hdmi_in/frontend/axi_gpio_hdmiin : None
# video/hdmi_in/frontend/axi_gpio_hdmiin : {}
# video/hdmi_in/frontend/axi_gpio_hdmiin : {}
# video/hdmi_in/frontend/axi_gpio_hdmiin : video/hdmi_in/frontend/axi_gpio_hdmiin
# video/hdmi_in/frontend/axi_gpio_hdmiin : <class 'pynq.lib.axigpio.AxiGPIO'>
# video/axi_vdma
# video/axi_vdma : 1124073472
# video/axi_vdma : 65536
# video/axi_vdma : xilinx.com:ip:axi_vdma:6.3
# video/axi_vdma : None
# video/axi_vdma : {'s2mm_introut': {'controller': 'system_interrupts', 'index': 0, 'fullpath': 'video/axi_vdma/s2mm_introut'}, 'mm2s_introut': {'controller': 'system_interrupts', 'index': 1, 'fullpath': 'video/axi_vdma/mm2s_introut'}}
# video/axi_vdma : {}
# video/axi_vdma : video/axi_vdma
# video/axi_vdma : <class 'pynq.lib.video.AxiVDMA'>
# btns_gpio
# btns_gpio : 1092681728
# btns_gpio : 65536
# btns_gpio : xilinx.com:ip:axi_gpio:2.0
# btns_gpio : None
# btns_gpio : {'ip2intc_irpt': {'controller': 'system_interrupts', 'index': 11, 'fullpath': 'btns_gpio/ip2intc_irpt'}}
# btns_gpio : {}
# btns_gpio : btns_gpio
# btns_gpio : <class 'pynq.lib.axigpio.AxiGPIO'>
# video/hdmi_in/color_convert
# video/hdmi_in/color_convert : 1136984064
# video/hdmi_in/color_convert : 65536
# video/hdmi_in/color_convert : xilinx.com:hls:color_convert:1.0
# video/hdmi_in/color_convert : None
# video/hdmi_in/color_convert : {}
# video/hdmi_in/color_convert : {}
# video/hdmi_in/color_convert : video/hdmi_in/color_convert
# video/hdmi_in/color_convert : <class 'pynq.lib.video.ColorConverter'>
# video/hdmi_out/color_convert
# video/hdmi_out/color_convert : 1137049600
# video/hdmi_out/color_convert : 65536
# video/hdmi_out/color_convert : xilinx.com:hls:color_convert:1.0
# video/hdmi_out/color_convert : None
# video/hdmi_out/color_convert : {}
# video/hdmi_out/color_convert : {}
# video/hdmi_out/color_convert : video/hdmi_out/color_convert
# video/hdmi_out/color_convert : <class 'pynq.lib.video.ColorConverter'>
# leds_gpio
# leds_gpio : 1092943872
# leds_gpio : 65536
# leds_gpio : xilinx.com:ip:axi_gpio:2.0
# leds_gpio : None
# leds_gpio : {}
# leds_gpio : {}
# leds_gpio : leds_gpio
# leds_gpio : <class 'pynq.lib.axigpio.AxiGPIO'>
# video/hdmi_out/frontend/hdmi_out_hpd_video
# video/hdmi_out/frontend/hdmi_out_hpd_video : 1092812800
# video/hdmi_out/frontend/hdmi_out_hpd_video : 65536
# video/hdmi_out/frontend/hdmi_out_hpd_video : xilinx.com:ip:axi_gpio:2.0
# video/hdmi_out/frontend/hdmi_out_hpd_video : None
# video/hdmi_out/frontend/hdmi_out_hpd_video : {}
# video/hdmi_out/frontend/hdmi_out_hpd_video : {}
# video/hdmi_out/frontend/hdmi_out_hpd_video : video/hdmi_out/frontend/hdmi_out_hpd_video
# video/hdmi_out/frontend/hdmi_out_hpd_video : <class 'pynq.lib.axigpio.AxiGPIO'>
# iop_pmoda/mb
# iop_pmoda/mb : 1073741824
# iop_pmoda/mb : 65536
# iop_pmoda/mb : xilinx.com:ip:microblaze:10.0
# iop_pmoda/mb : None
# iop_pmoda/mb : {}
# iop_pmoda/mb : {}
# iop_pmoda/mb : iop_pmoda/mb
# iop_pmoda/mb : <class 'pynq.overlay.DefaultIP'>
# iop_pmoda/mb_bram_ctrl
# iop_pmoda/mb_bram_ctrl : 1073741824
# iop_pmoda/mb_bram_ctrl : 65536
# iop_pmoda/mb_bram_ctrl : xilinx.com:ip:axi_bram_ctrl:4.0
# iop_pmoda/mb_bram_ctrl : None
# iop_pmoda/mb_bram_ctrl : {}
# iop_pmoda/mb_bram_ctrl : {}
# iop_pmoda/mb_bram_ctrl : iop_pmoda/mb_bram_ctrl
# iop_pmoda/mb_bram_ctrl : <class 'pynq.overlay.DefaultIP'>
# iop_pmodb/mb
# iop_pmodb/mb : 1107296256
# iop_pmodb/mb : 65536
# iop_pmodb/mb : xilinx.com:ip:microblaze:10.0
# iop_pmodb/mb : None
# iop_pmodb/mb : {}
# iop_pmodb/mb : {}
# iop_pmodb/mb : iop_pmodb/mb
# iop_pmodb/mb : <class 'pynq.overlay.DefaultIP'>
# iop_pmodb/mb_bram_ctrl
# iop_pmodb/mb_bram_ctrl : 1107296256
# iop_pmodb/mb_bram_ctrl : 65536
# iop_pmodb/mb_bram_ctrl : xilinx.com:ip:axi_bram_ctrl:4.0
# iop_pmodb/mb_bram_ctrl : None
# iop_pmodb/mb_bram_ctrl : {}
# iop_pmodb/mb_bram_ctrl : {}
# iop_pmodb/mb_bram_ctrl : iop_pmodb/mb_bram_ctrl
# iop_pmodb/mb_bram_ctrl : <class 'pynq.overlay.DefaultIP'>
# iop_arduino/mb
# iop_arduino/mb : 1140850688
# iop_arduino/mb : 65536
# iop_arduino/mb : xilinx.com:ip:microblaze:10.0
# iop_arduino/mb : None
# iop_arduino/mb : {}
# iop_arduino/mb : {}
# iop_arduino/mb : iop_arduino/mb
# iop_arduino/mb : <class 'pynq.overlay.DefaultIP'>
# iop_arduino/mb_bram_ctrl
# iop_arduino/mb_bram_ctrl : 1140850688
# iop_arduino/mb_bram_ctrl : 65536
# iop_arduino/mb_bram_ctrl : xilinx.com:ip:axi_bram_ctrl:4.0
# iop_arduino/mb_bram_ctrl : None
# iop_arduino/mb_bram_ctrl : {}
# iop_arduino/mb_bram_ctrl : {}
# iop_arduino/mb_bram_ctrl : iop_arduino/mb_bram_ctrl
# iop_arduino/mb_bram_ctrl : <class 'pynq.overlay.DefaultIP'>
# video/hdmi_in/pixel_pack
# video/hdmi_in/pixel_pack : 1136918528
# video/hdmi_in/pixel_pack : 65536
# video/hdmi_in/pixel_pack : xilinx.com:hls:pixel_pack:1.0
# video/hdmi_in/pixel_pack : None
# video/hdmi_in/pixel_pack : {}
# video/hdmi_in/pixel_pack : {}
# video/hdmi_in/pixel_pack : video/hdmi_in/pixel_pack
# video/hdmi_in/pixel_pack : <class 'pynq.lib.video.PixelPacker'>
# video/hdmi_out/pixel_unpack
# video/hdmi_out/pixel_unpack : 1137115136
# video/hdmi_out/pixel_unpack : 65536
# video/hdmi_out/pixel_unpack : xilinx.com:hls:pixel_unpack:1.0
# video/hdmi_out/pixel_unpack : None
# video/hdmi_out/pixel_unpack : {}
# video/hdmi_out/pixel_unpack : {}
# video/hdmi_out/pixel_unpack : video/hdmi_out/pixel_unpack
# video/hdmi_out/pixel_unpack : <class 'pynq.lib.video.PixelPacker'>
# rgbleds_gpio
# rgbleds_gpio : 1092878336
# rgbleds_gpio : 65536
# rgbleds_gpio : xilinx.com:ip:axi_gpio:2.0
# rgbleds_gpio : None
# rgbleds_gpio : {}
# rgbleds_gpio : {}
# rgbleds_gpio : rgbleds_gpio
# rgbleds_gpio : <class 'pynq.lib.axigpio.AxiGPIO'>
# switches_gpio
# switches_gpio : 1092616192
# switches_gpio : 65536
# switches_gpio : xilinx.com:ip:axi_gpio:2.0
# switches_gpio : None
# switches_gpio : {'ip2intc_irpt': {'controller': 'system_interrupts', 'index': 12, 'fullpath': 'switches_gpio/ip2intc_irpt'}}
# switches_gpio : {}
# switches_gpio : switches_gpio
# switches_gpio : <class 'pynq.lib.axigpio.AxiGPIO'>
# system_interrupts
# system_interrupts : 1098907648
# system_interrupts : 65536
# system_interrupts : xilinx.com:ip:axi_intc:4.1
# system_interrupts : None
# system_interrupts : {}
# system_interrupts : {}
# system_interrupts : system_interrupts
# system_interrupts : <class 'pynq.overlay.DefaultIP'>
# trace_analyzer_pmoda/trace_cntrl_32_0
# trace_analyzer_pmoda/trace_cntrl_32_0 : 2210463744
# trace_analyzer_pmoda/trace_cntrl_32_0 : 65536
# trace_analyzer_pmoda/trace_cntrl_32_0 : xilinx.com:hls:trace_cntrl_32:1.4
# trace_analyzer_pmoda/trace_cntrl_32_0 : None
# trace_analyzer_pmoda/trace_cntrl_32_0 : {}
# trace_analyzer_pmoda/trace_cntrl_32_0 : {}
# trace_analyzer_pmoda/trace_cntrl_32_0 : trace_analyzer_pmoda/trace_cntrl_32_0
# trace_analyzer_pmoda/trace_cntrl_32_0 : <class 'pynq.overlay.DefaultIP'>
# trace_analyzer_arduino/trace_cntrl_64_0
# trace_analyzer_arduino/trace_cntrl_64_0 : 2210398208
# trace_analyzer_arduino/trace_cntrl_64_0 : 65536
# trace_analyzer_arduino/trace_cntrl_64_0 : xilinx.com:hls:trace_cntrl_64:1.4
# trace_analyzer_arduino/trace_cntrl_64_0 : None
# trace_analyzer_arduino/trace_cntrl_64_0 : {}
# trace_analyzer_arduino/trace_cntrl_64_0 : {}
# trace_analyzer_arduino/trace_cntrl_64_0 : trace_analyzer_arduino/trace_cntrl_64_0
# trace_analyzer_arduino/trace_cntrl_64_0 : <class 'pynq.overlay.DefaultIP'>
# video/hdmi_in/frontend/vtc_in
# video/hdmi_in/frontend/vtc_in : 1136852992
# video/hdmi_in/frontend/vtc_in : 65536
# video/hdmi_in/frontend/vtc_in : xilinx.com:ip:v_tc:6.1
# video/hdmi_in/frontend/vtc_in : None
# video/hdmi_in/frontend/vtc_in : {}
# video/hdmi_in/frontend/vtc_in : {}
# video/hdmi_in/frontend/vtc_in : video/hdmi_in/frontend/vtc_in
# video/hdmi_in/frontend/vtc_in : <class 'pynq.overlay.DefaultIP'>
# video/hdmi_out/frontend/vtc_out
# video/hdmi_out/frontend/vtc_out : 1136787456
# video/hdmi_out/frontend/vtc_out : 65536
# video/hdmi_out/frontend/vtc_out : xilinx.com:ip:v_tc:6.1
# video/hdmi_out/frontend/vtc_out : None
# video/hdmi_out/frontend/vtc_out : {}
# video/hdmi_out/frontend/vtc_out : {}
# video/hdmi_out/frontend/vtc_out : video/hdmi_out/frontend/vtc_out
# video/hdmi_out/frontend/vtc_out : <class 'pynq.overlay.DefaultIP'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-679b9a1f410f> in <module>()
# ----> 1 for values in base.ip_dict[iop_arduino/mb]:
#       2     print(values)
#
# NameError: name 'iop_arduino' is not defined
