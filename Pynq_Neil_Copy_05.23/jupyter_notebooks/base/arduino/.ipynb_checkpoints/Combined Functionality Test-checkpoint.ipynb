# %%
from pynq.overlays.base import BaseOverlay
import time
base = BaseOverlay("base.bit")

# %%
from pynq.lib.arduino import Arduino_SPOT

tmp = Arduino_SPOT(base.ARDUINO,Arduino_SPOT)

# %%
tmp.play_sequence([16,-100,16,-100,16,-50,16])
time.sleep(20)
tmp.stop()

# %%
i = 0
while i <= 60:
    print(i, " seconds")
    print(tmp.get_gyro())
    print(tmp.get_compass())
    print(tmp.get_accl())
    print(tmp.get_euler())
    print(tmp.get_temperature())
    time.sleep(1)
    i = i + 1
# Out:
# 0  seconds
# [0.16, 2.28, 0.16]
# [359.69, -3.12, 5.56]
# 29
# 1  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 2  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 3  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 4  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 5  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 6  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 7  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 8  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 9  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 10  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 11  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 12  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 13  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 14  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 15  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 16  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 17  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 18  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 19  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 20  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 21  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 22  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 23  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 24  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 25  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 26  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 27  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 28  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 29  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 30  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 31  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 32  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 33  seconds
# [0.29, -0.5, 0.89]
# [359.69, -3.12, 5.56]
# 29
# 34  seconds
# [0.29, -0.5, 0.89]
# [358.62, -2.88, 6.19]
# 29
# 35  seconds
# [0.29, -0.46, 0.99]
# [319.0, -7.5, 6.19]
# 29
# 36  seconds
# [0.29, -1.2, 0.99]
# [319.94, -8.56, 8.0]
# 29
# 37  seconds
# [0.29, -1.37, 1.28]
# [354.62, 0.81, 3.44]
# 29
# 38  seconds
# [0.29, 0.13, 0.55]
# [303.44, -14.5, 6.06]
# 29
# 39  seconds
# [0.29, -2.32, 0.97]
# [351.31, -5.12, 1.25]
# 29
# 40  seconds
# [0.29, -0.82, 0.2]
# [351.5, -4.44, -2.56]
# 29
# 41  seconds
# [0.29, -0.71, -0.41]
# [351.5, -4.25, -2.38]
# 29
# 42  seconds
# [0.29, -0.68, -0.38]
# [351.5, -4.25, -2.38]
# 29
# 43  seconds
# [0.29, -0.68, -0.38]
# [351.5, -4.25, -2.38]
# 29
# 44  seconds
# [0.29, -0.68, -0.38]
# [351.5, -4.25, -2.38]
# 29
# 45  seconds
# [0.29, -0.68, -0.38]
# [341.69, -7.56, -3.44]
# 29
# 46  seconds
# [0.29, -1.21, -0.55]
# [246.94, 4.31, -11.31]
# 29
# 47  seconds
# [0.29, 0.69, -1.81]
# [291.38, 3.81, -15.06]
# 29
# 48  seconds
# [0.29, 0.61, -2.41]
# [336.38, 0.06, -7.44]
# 29
# 49  seconds
# [0.29, 0.01, -1.19]
# [273.06, 5.25, -4.94]
# 29
# 50  seconds
# [0.29, 0.84, -0.79]
# [227.56, 11.88, -5.31]
# 29
# 51  seconds
# [0.29, 1.9, -0.85]
# [227.0, 17.5, 2.56]
# 29
# 52  seconds
# [0.29, 2.8, 0.41]
# [227.5, 19.0, 4.0]
# 29
# 53  seconds
# [0.29, 3.04, 0.64]
# [226.12, 19.38, 5.88]
# 29
# 54  seconds
# [0.29, 3.1, 0.94]
# [245.06, 24.06, 9.31]
# 29
# 55  seconds
# [0.29, 3.85, 1.49]
# [314.44, 4.38, -20.12]
# 29
# 56  seconds
# [0.29, 0.7, -3.22]
# [315.0, -1.06, -14.88]
# 29
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ca7fff588382> in <module>()
#       7     print(tmp.get_euler())
#       8     print(tmp.get_temperature())
# ----> 9     time.sleep(1)
#      10     i = i + 1
#
# KeyboardInterrupt:

# %%
i = 0
while i <= 60:
    print(i, " seconds")
    [ex, ey, ez] = tmp.get_euler()
    print(ex)
    time.sleep(1)
    i = i + 1
    if(ex > 350.0) :
        tmp.play_sequence([16])
        tmp.poll()
        time.sleep(1)
        i = i + 1
    if(ex < 10.0) :
        tmp.play_sequence([16])
        tmp.poll()
        time.sleep(1)
        i = i + 1
        
tmp.stop()
